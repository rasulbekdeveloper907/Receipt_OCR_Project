# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
sys.path.append(str(PROJECT_ROOT))

# %%
from Source.loader import DatasetLoader
from Source.visualizer import ReceiptVisualizer

# %%
loader = DatasetLoader("../Data/Raw")

train = loader.load_train()

# %%
visualizer = ReceiptVisualizer(train)

# %%
visualizer.show_image()

# %%
visualizer.show_image(25)

# %%
visualizer.show_image(100)
