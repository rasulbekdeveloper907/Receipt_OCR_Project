# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
sys.path.append(str(PROJECT_ROOT))

# %%
from Source.loader import DatasetLoader
from Source.explorer import DatasetExplorer

# %%
loader = DatasetLoader("../Data/Raw")

train = loader.load_train()

# %%
explorer = DatasetExplorer(train)

# %%
explorer.summary()
# Out:
# ============================================================
# IMAGE STATISTICS
# ============================================================
# Total Images : 626
# Min Width    : 436
# Max Width    : 4961
# Average Width: 1325.75
#
# Min Height   : 605
# Max Height   : 7016
# Average Height: 2355.87
#
# ============================================================
# ENTITY STATISTICS
# ============================================================
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 explorer.summary()
#
# File c:\Users\Rasulbekk\Desktop\Receipt_OCR_Project\Source\explorer.py:113, in DatasetExplorer.summary(self)
#     109 self.image_statistics()
#     111 print()
# --> 113 self.entity_statistics()
#     115 print()
#     117 self.ocr_statistics()
#
# File c:\Users\Rasulbekk\Desktop\Receipt_OCR_Project\Source\explorer.py:67, in DatasetExplorer.entity_statistics(self)
#      64 if entity["company"]:
#      65     total_company += 1
# ---> 67 if entity["address"]:
#      68     total_address += 1
#      70 if entity["date"]:
#
# KeyError: 'address'
