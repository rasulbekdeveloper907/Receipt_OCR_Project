# %%
import sys
from pathlib import Path

# Loyiha root papkasini topish
PROJECT_ROOT = Path.cwd().parent
sys.path.append(str(PROJECT_ROOT))

# %%
from Source.validator import DatasetValidator

# %%
DATASET_PATH = PROJECT_ROOT / "Data" / "Raw"

validator = DatasetValidator(DATASET_PATH)
validator.validate()
# Out:
# =======================================================
#         SROIE 2019 DATASET VALIDATION
# =======================================================
#
# [TRAIN]
# Images   : 626
# Boxes    : 626
# Entities : 626
#
# Status : VALID
#
# [TEST]
# Images   : 347
# Boxes    : 347
# Entities : 347
#
# Status : VALID
#
# =======================================================
# Dataset Status : VALID
# =======================================================
