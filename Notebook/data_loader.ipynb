# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
sys.path.append(str(PROJECT_ROOT))

# %%
from Source.loader import DatasetLoader

# %%
loader = DatasetLoader(PROJECT_ROOT / "Data" / "Raw")

# %%
train_dataset = loader.load_train()

len(train_dataset)
# Out:
# 626

# %%
test_dataset = loader.load_test()

len(test_dataset)
# Out:
# 347

# %%
train_dataset[0]
# Out:
# {'id': 'X00016469612',
#  'image_path': WindowsPath('c:/Users/Rasulbekk/Desktop/Receipt_OCR_Project/Data/Raw/train/img/X00016469612.jpg'),
#  'box_path': WindowsPath('c:/Users/Rasulbekk/Desktop/Receipt_OCR_Project/Data/Raw/train/box/X00016469612.txt'),
#  'entity_path': WindowsPath('c:/Users/Rasulbekk/Desktop/Receipt_OCR_Project/Data/Raw/train/entities/X00016469612.txt')}
